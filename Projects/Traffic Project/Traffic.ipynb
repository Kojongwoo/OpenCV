# %%
# pip install osmnx
# pip install networkx
# pip install --upgrade pip
# pip install geopandas

# %%
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt

# 가져올 지역 설정 (서울 전체)
place = place = "Seoul, South Korea"

# 도로 네트워크 가져오기 (drive: 자동차 도로만)
G = ox.graph_from_place(place, network_type="drive")

# 그래프 시각화
fig, ax = ox.plot_graph(G, node_size=5, edge_linewidth=0.8)

# %%
# 현재 내 위치 : 서경대학교 북악관, 좌표: 37.616059, 127.012068
# 목표 위치 : 서울특별시 송파구 잠실 4동, 좌표: 37.51964, 127.10909

# %%
# 출발지와 목적지 좌표 (예: 학교 -> 잠실4동)
origin = (37.616059, 127.012068)  #  학교
destination = (37.51964, 127.10909)  #  잠실4동

# 가장 가까운 노드 찾기
orig_node = ox.distance.nearest_nodes(G, X=origin[1], Y=origin[0])
dest_node = ox.distance.nearest_nodes(G, X=destination[1], Y=destination[0])

# 다익스트라 최단 경로
route = nx.shortest_path(G, orig_node, dest_node, weight="length")

# 경로 시각화
fig, ax = ox.plot_graph_route(G, route, route_linewidth=4, node_size=5)

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
